# %% [markdown]
# # W&G Baird Printing Analytics
#
# This notebook is a lightweight companion to the production pipeline. Use it for exploration, teaching, or dissertation appendices. The authoritative refreshable workflow is `../main.py`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from main import run_pipeline

outputs = run_pipeline(PROJECT_ROOT / 'data' / 'raw' / 'sample_dataset.xlsx')
outputs

# %%
import pandas as pd

tables = PROJECT_ROOT / 'outputs' / 'tables'
pd.read_csv(tables / 'top_customers_by_va.csv').head(10)

# %%
pd.read_csv(tables / 'model_performance.csv')

# %% [markdown]
# The generated business report is available at `../outputs/reports/business_report.html` and `../outputs/reports/business_report.md`.
